# %%
import pandas as pd

# %%
data = pd.read_csv('08-19-data.csv')
data.head()
# Out:
#   Sukupuoli  Ikä  Pituus (cm)  Paino (kg)   BMI  Vuorokausiaineenvaihdunta  \
# 0      mies   20        191.0        66.4  18.2                       2226
# 1      mies   22        181.6        80.8  24.5                       2396
# 2      mies   22        185.8        79.0  22.9                       2391
# 3      mies   33        170.2        75.1  25.9                       2154
# 4      mies   33        183.8       109.2  32.3                       2807
#
#    Rasvaprosentti  Rasvamassa (kg)  Rasvaton massa (kg)  Lihasmassa (kg)  \
# 0             8.0              5.3                 61.1             25.8
# 1            15.9             12.8                 68.0             29.3
# 2            12.8             10.1                 68.9             26.7
# 3            24.1             18.1                 57.0             26.1
# 4            30.0             32.8                 76.4             33.1
#
#    Lihasmassan osuus rasvattomasta  6min viitearvo  6min tulos  \
# ...

# %%
data = data.drop(labels=['6min viitearvo', 'testisyke/max syke', 'Kuntotaso vo2max (1-7)'], axis=1)
data.head()
# Out:
#   Sukupuoli  Ikä  Pituus (cm)  Paino (kg)   BMI  Vuorokausiaineenvaihdunta  \
# 0      mies   20        191.0        66.4  18.2                       2226
# 1      mies   22        181.6        80.8  24.5                       2396
# 2      mies   22        185.8        79.0  22.9                       2391
# 3      mies   33        170.2        75.1  25.9                       2154
# 4      mies   33        183.8       109.2  32.3                       2807
#
#    Rasvaprosentti  Rasvamassa (kg)  Rasvaton massa (kg)  Lihasmassa (kg)  \
# 0             8.0              5.3                 61.1             25.8
# 1            15.9             12.8                 68.0             29.3
# 2            12.8             10.1                 68.9             26.7
# 3            24.1             18.1                 57.0             26.1
# 4            30.0             32.8                 76.4             33.1
#
# ...

# %%
data.columns
# Out:
# Index(['Sukupuoli', 'Ikä', 'Pituus (cm)', 'Paino (kg)', 'BMI',
#        'Vuorokausiaineenvaihdunta', 'Rasvaprosentti', 'Rasvamassa (kg)',
#        'Rasvaton massa (kg)', 'Lihasmassa (kg)',
#        'Lihasmassan osuus rasvattomasta', '6min tulos', 'syke testin lopussa',
#        'vo2max', 'Maksimivoima (kg)', 'maksimivoima/paino'],
#       dtype='object')

# %%
data
# Out:
#    Sukupuoli  Ikä  Pituus (cm)  Paino (kg)   BMI  Vuorokausiaineenvaihdunta  \
# 0       mies   20        191.0        66.4  18.2                       2226
# 1       mies   22        181.6        80.8  24.5                       2396
# 2       mies   22        185.8        79.0  22.9                       2391
# 3       mies   33        170.2        75.1  25.9                       2154
# 4       mies   33        183.8       109.2  32.3                       2807
# 5       mies   34        202.5       147.6  36.0                       3555
# 6       mies   38        175.0        78.6  25.7                       2206
# 7       mies   39        174.7       100.3  32.9                       2561
# 8       mies   44        179.2        83.2  25.9                       2266
# 9       mies   45        172.5        91.3  30.7                       2354
# 10      mies   47        173.6        62.1  20.6                       1858
# ...

# %%
data.to_csv('08-19-streamlit-data.csv', index=False)
